# %%
import os
print(os.listdir())
# Out:
# ['Untitled 14.ipynb', 'Untitled 10.ipynb', 'Untitled 9.ipynb', 'Untitled 12.ipynb', '인프기 기말4.ipynb', 'Untitled 8.ipynb', '인프기 기말2.ipynb', 'Untitled 13.ipynb', 'Untitled 11.ipynb', 'welcome', 'Untitled 6.ipynb', 'iris.csv', 'Untitled 4.ipynb', 'Untitled 2.ipynb', '.ipynb_checkpoints', 'Untitled 5.ipynb', 'Untitled 7.ipynb', 'Untitled1.ipynb', 'iris.csv.csv', 'cars.csv', 'data', 'Untitled.ipynb', '인프기 기말.ipynb', '인프_1_복습.ipynb', '인프기 기말 3.ipynb', 'Untitled 3.ipynb']
